# %% [markdown]
# # 📚 [Topic Name]
# > Example: NumPy Arrays / Pandas GroupBy / SQL JOIN

# %% [markdown]
# ---
# # 🎯 Learning Objective
# Today I want to learn:
# - [ ]
# - [ ]
# - [ ]

# %% [markdown]
# ---
# # 🧠 Concept
#
# ## What is it?
# *(Explain it in your own words.)*

# %% [markdown]
# ## Why do we use it?
# *(When is it useful?)*

# %% [markdown]
# ## When is it used in Business Analytics?
# *(Real-world use case)*

# %% [markdown]
# ---
# # 📝 Syntax
#
# ## Basic Syntax

# %%
# Basic Syntax

# %% [markdown]
# ## Common Variations

# %%
# Common Variations

# %% [markdown]
# ---
# # 🧪 Small Examples
#
# ## Example 1

# %%
# Example 1

# %% [markdown]
# ## Example 2

# %%
# Example 2

# %% [markdown]
# ## Example 3

# %%
# Example 3

# %% [markdown]
# ---
# # ⚠️ Common Mistakes
#
# - Mistake 1
# - Mistake 2
# - Mistake 3

# %% [markdown]
# ---
# # 💡 Tips
# Useful tips or shortcuts
#
# -
# -
# -

# %% [markdown]
# ---
# # 🔗 Related Concepts
#
# ```
# Python
#     ↓
# NumPy
#     ↓
# Pandas
#     ↓
# SQL
#     ↓
# Tableau
# ```
#
# *How is today's topic connected to other concepts?*

# %% [markdown]
# ---
# # 💼 Business Example
# *How would a Business Analyst use this?*
#
# **Example:**

# %% [markdown]
# ---
# # 📝 Summary
# *Write today's concept in 3~5 sentences.*

# %% [markdown]
# ---
# # 📌 One Sentence Summary
# Today's topic in ONE sentence.
#
# >

# %% [markdown]
# ---
# # ❓ Review Questions
#
# **Q1.**
#
# **Q2.**
#
# **Q3.**
#
# **Q4.**
#
# **Q5.**
#
# ---
# *📅 Try answering these again in a few days.*
